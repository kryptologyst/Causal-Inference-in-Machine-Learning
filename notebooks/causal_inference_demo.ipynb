# %% [markdown]
# # Causal Inference in Machine Learning
#
# **Author:** [kryptologyst](https://github.com/kryptologyst)
# **GitHub:** https://github.com/kryptologyst
#
# This notebook demonstrates various causal inference methods for estimating treatment effects from observational data.
#
# ## ⚠️ Important Disclaimers
#
# - **Research/Educational Purpose Only**: This notebook is designed for research and educational purposes
# - **Not for Production Decisions**: Do not use these methods for critical production decisions without expert review
# - **Causal Claims Require Domain Expertise**: Causal inference requires deep domain knowledge and careful validation
# - **Observational Data Limitations**: Results from observational studies may not generalize to new contexts

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# Set style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# Import causal inference modules
from src.data.synthetic import generate_synthetic_data, generate_heterogeneous_data
from src.models.propensity_score import PropensityScoreMatching
from src.models.ipw import InverseProbabilityWeighting
from src.models.double_ml import DoubleMachineLearning
from src.models.causal_forest import CausalForest
from src.evaluation.metrics import evaluate_causal_effect, create_evaluation_report
from src.visualization.plots import plot_treatment_effects, plot_propensity_scores, plot_balance_before_after
from src.utils.helpers import set_random_seed, check_data_quality

# Set random seed for reproducibility
set_random_seed(42)

print("✅ All imports successful!")
